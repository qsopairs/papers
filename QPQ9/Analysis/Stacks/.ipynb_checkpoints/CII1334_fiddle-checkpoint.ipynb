# %% [markdown]
# # Fiddling with CII 1334 stacks from QPQ7 + MgII

# %%
# %matplotlib inline

# %%
# imports
from __future__ import print_function,absolute_import,division,unicode_literals
import numpy as np
import glob,os,sys,copy 
from scipy import stats as scistats
import matplotlib as mpl
mpl.rcParams['font.family']='stixgeneral'
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
from astropy.table import QTable,Table
from astropy.io import ascii
from astropy import units as u
from astropy import constants as const
from linetools.spectralline import AbsLine
from xastropy.igm.abs_sys import abssys_utils as abssys
from xastropy import spec as xpsec
from xastropy.plotting import utils as xputils
from xastropy.xutils import xdebug as xdb
from xastropy.obs import radec as xor
from xastropy.atomic import ionization as xai
sys.path.append(os.path.abspath("../../../../py"))
from enigma.qpq import utils as qpqutils
from enigma.qpq import spec as qpqs
from enigma.qpq import stacks as qpqk
sys.path.append(os.path.abspath("../py"))
import qpq9_analy as qpq9a
sys.path.append(os.path.abspath("./py"))
import qpq9_stacks as qpq9k
# Out:
# /Users/lwymarie/anaconda/lib/python2.7/site-packages/astroquery/sdss/__init__.py:28: UserWarning: Experimental: SDSS has not yet been refactored to have its API match the rest of astroquery (but it's nearly there).
#   warnings.warn("Experimental: SDSS has not yet been refactored to have its API "

# %% [markdown]
# ## Load stack_tup

# %%
reload(qpqk)
reload(qpq9k)
stack_tup0 = qpq9k.qpq9(passback=True)
# Out:
# Reading /Users/lwymarie/QSOClustering//tex/QPQ9/Analysis/qpq9_final.fits
# length of sample after and before culling 21 32
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux/SDSSJ022519.50+004823.7_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux/SDSSJ022519.50+004823.7_b1200_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0/SDSSJ022519.50+004823.7.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (36.33126966932258, 0.80658382157506181) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux/SDSSJ022519.50+004823.7_F.fits.gz for BOSSJ0225+0048
# /Users/lwymarie/python/linetools/linetools/spectra/xspectrum1d.py:155: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ080048.74+354231.3_b1200_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux/SDSSJ080048.74+354231.3.fits in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (120.20306831966985, 35.708697654587503) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ080048.74+354231.3_b1200_F.fits.gz for APOJ0800+3542
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ083757.13+383722.4_b1200_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (129.48804795689273, 38.622892836270111) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ083757.13+383722.4_b1200_F.fits.gz for APOJ0837+3837
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ084159.26+392140.0_b1200_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux/SDSSJ084159.26+392140.0.fits in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0/SDSSJ084159.26+392140.0.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (130.49691045554408, 39.361107534736384) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ084159.26+392140.0_b1200_F.fits.gz for BOSSJ0841+3921
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux/SDSSJ085357.49-001106.1_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux/SDSSJ085357.49-001106.2.fits in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0/SDSSJ085357.49-001106.1.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (133.48955387431641, -0.18505125520285617) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux/SDSSJ085357.49-001106.1_F.fits.gz for BOSSJ0853-0011
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux/SDSSJ091338.97-010704.6_b600_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux/SDSSJ091338.97-010704.6_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux/SDSSJ091338.97-010704.6_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (138.41238462981659, -1.1179513461444508) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0/SDSSJ143344.55+064111.9.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (218.43562653234838, 6.6866487021302365) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0/SDSSJ143344.55+064111.9.fits for BOSSJ1433+0641
# /Users/lwymarie/python/linetools/linetools/spectra/io.py:203: UserWarning: Continuum size does not match native spectrum
#   warnings.warn("Continuum size does not match native spectrum")
# /Users/lwymarie/python/linetools/linetools/spectra/io.py:204: UserWarning: Continuing under the assumption that this is due to a masked array
#   warnings.warn("Continuing under the assumption that this is due to a masked array")
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux/SDSSJ155325.89+192137.7_b1200_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux/SDSSJ155325.89+192137.7_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (238.35786023389483, 19.360470497723252) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux/SDSSJ155325.89+192137.7_F.fits.gz for APOJ1553+1921
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# Your file is /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux/SDSSJ162737.25+460609.3_F.fits.gz in folder /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GMOS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/GNIRS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/HIRES_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/ISAAC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/LRIS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MAGE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MIKE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MMT_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MODS_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/MOSFIRE_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRI_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/NIRSPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/TRIPLESPEC_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/XSHOOTER_redux
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_2
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_7_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/BOSS/v5_6_0
# In folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# No file for (246.90520067725595, 46.1025927908453) in folder /Users/lwymarie/Dropbox//QSOPairs/data/SDSS
# Using /Users/lwymarie/Dropbox//QSOPairs/data/ESI_redux/SDSSJ162737.25+460609.3_F.fits.gz for APOJ1627+4606

# %% [markdown]
# ## Stack and Plot

# %% [markdown]
# ### All

# %%
fin_velo, stck_img, stck_msk, all_dict = stack_tup0
stack_tup = (fin_velo, stck_img, stck_msk, all_dict)
#
fin_velo, fin_flx, all_dict = qpqk.stack_avg(stack_tup)
plt.figure(figsize=(8,5),dpi=1200)
plt.plot(fin_velo, fin_flx, drawstyle='steps',linewidth=2.)
plt.xlabel('Relative Velocity', size=12.)
plt.show()

# %% [markdown]
# ### Mask DLA

# %%
# Mask
fin_velo, stck_img, stck_msk, all_dict = stack_tup0
stck_mskN = copy.deepcopy(stck_msk)

# %%
len(stck_mskN)
# Out:
# 21

# %%
idx_mask = [11]
for idx in idx_mask:
    stck_mskN[idx,:] = 0.
# Stack
stack_tup = (fin_velo, stck_img, stck_mskN, all_dict)
fin_velo, fin_flx, all_dict = qpqk.stack_avg(stack_tup)
# Plot
plt.figure(figsize=(8,5),dpi=1200)
plt.plot(fin_velo, fin_flx, drawstyle='steps',linewidth=2.)
plt.xlim(-2000, 2000)
plt.xlabel('Relative Velocity', size=12.)
plt.show()

# %% [markdown]
# ### DLA and noisy spectra

# %%
# Mask
fin_velo, stck_img, stck_msk, all_dict = stack_tup0
stck_mskN = copy.deepcopy(stck_msk)

# %%
len(stck_mskN)
# Out:
# 21

# %%
idx_mask = [10,15]
for idx in idx_mask:
    stck_mskN[idx,:] = 0.
# Stack
stack_tup = (fin_velo, stck_img, stck_mskN, all_dict)
fin_velo, fin_flx, all_dict = qpqk.stack_avg(stack_tup)
# Plot
plt.figure(figsize=(12,8),dpi=1200)
plt.plot(fin_velo, fin_flx, drawstyle='steps',linewidth=2.)
plt.xlim(-2000, 2000)
plt.xlabel('Relative Velocity', size=12.)
plt.show()
