# %% [markdown]
# # Check KG MF continua

# %%
# %matplotlib notebook

# %%
#imports

# %% [markdown]
# ## J1617+0919

# %%
spfile = '/Volumes/xmen/greymalkin/raid/Raw_IGMSpec/BOSS/BOSSLyaDR12_spectra_v1.0/5205/speclya-5205-56040-0096.fits.gz'

# %%
hdul = fits.open(spfile)
data = Table(hdul[1].data)
data[0:3]
# Out:
# <Table length=3>
#   FLUX    LOGLAM    IVAR   AND_MASK ... MASK_COMB DLA_CORR NOISE_CORR   CONT
# float32  float32  float32   int32   ...   int32   float32   float32   float32
# -------- ------- --------- -------- ... --------- -------- ---------- -------
# -8.17045  3.5515 0.0260615        0 ...         4      1.0        1.0     0.0
#  7.70244  3.5516 0.0346259        0 ...         4      1.0        1.0     0.0
#  1.98176  3.5517  0.034893        0 ...         4      1.0        1.0     0.0

# %%
wv = 10.**data['LOGLAM']

# %% [markdown]
# ### Plot

# %%
plt.clf()
ax = plt.gca()
ax.plot(wv, data['FLUX'], 'k')
# Continuum
ax.plot(wv, data['CONT'], 'r--')
ax.set_xlim(3600., 5000.)
ax.set_ylim(0., 14.)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
